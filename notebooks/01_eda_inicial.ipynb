# %% [markdown]
# # Análisis Exploratorio Inicial
#
# Proyecto: **Clasificación de Cáncer de Mama**
#
# En este notebook realizamos una primera exploración del dataset de cáncer de mama.
#
# ---

# %% [markdown]
# ## 1. Importar librerías

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 2. Cargar el dataset
#
# El archivo se asume en la ruta `data/raw/cancer_mama.csv` (puedes ajustar el nombre si es diferente).

# %%
ruta_dataset = Path("../data/raw/cancer_mama.csv")

if not ruta_dataset.exists():
    raise FileNotFoundError(f"No se encontró el archivo en: {ruta_dataset.resolve()}")

df = pd.read_csv(ruta_dataset)
print("✅ Datos cargados correctamente")
print(df.shape)
df.head()
# Out:
# ✅ Datos cargados correctamente
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 3. Información general del dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    str
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), str(1)
# memory usage: 146.8 KB

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.describe().T
# Out:
#                          count          mean            std      min  \
# id                      569.00 30,371,831.43 125,020,585.61 8,670.00
# radius_mean             569.00         14.13           3.52     6.98
# texture_mean            569.00         19.29           4.30     9.71
# perimeter_mean          569.00         91.97          24.30    43.79
# area_mean               569.00        654.89         351.91   143.50
# smoothness_mean         569.00          0.10           0.01     0.05
# compactness_mean        569.00          0.10           0.05     0.02
# concavity_mean          569.00          0.09           0.08     0.00
# concave points_mean     569.00          0.05           0.04     0.00
# symmetry_mean           569.00          0.18           0.03     0.11
# fractal_dimension_mean  569.00          0.06           0.01     0.05
# radius_se               569.00          0.41           0.28     0.11
# texture_se              569.00          1.22           0.55     0.36
# perimeter_se            569.00          2.87           2.02     0.76
# area_se                 569.00         40.34          45.49     6.80
# smoothness_se           569.00          0.01           0.00     0.00
# compactness_se          569.00          0.03           0.02     0.00
# concavity_se            569.00          0.03           0.03     0.00
# concave points_se       569.00          0.01           0.01     0.00
# symmetry_se             569.00          0.02           0.01     0.01
# fractal_dimension_se    569.00          0.00           0.00     0.00
# radius_worst            569.00         16.27           4.83     7.93
# texture_worst           569.00         25.68           6.15    12.02
# perimeter_worst         569.00        107.26          33.60    50.41
# area_worst              569.00        880.58         569.36   185.20
# smoothness_worst        569.00          0.13           0.02     0.07
# compactness_worst       569.00          0.25           0.16     0.03
# concavity_worst         569.00          0.27           0.21     0.00
# concave points_worst    569.00          0.11           0.07     0.00
# symmetry_worst          569.00          0.29           0.06     0.16
# fractal_dimension_worst 569.00          0.08           0.02     0.06
# Unnamed: 32               0.00           NaN            NaN      NaN
#
#                                25%        50%          75%            max
# id                      869,218.00 906,024.00 8,813,129.00 911,320,502.00
# radius_mean                  11.70      13.37        15.78          28.11
# texture_mean                 16.17      18.84        21.80          39.28
# perimeter_mean               75.17      86.24       104.10         188.50
# area_mean                   420.30     551.10       782.70       2,501.00
# smoothness_mean               0.09       0.10         0.11           0.16
# compactness_mean              0.06       0.09         0.13           0.35
# concavity_mean                0.03       0.06         0.13           0.43
# concave points_mean           0.02       0.03         0.07           0.20
# symmetry_mean                 0.16       0.18         0.20           0.30
# fractal_dimension_mean        0.06       0.06         0.07           0.10
# radius_se                     0.23       0.32         0.48           2.87
# texture_se                    0.83       1.11         1.47           4.88
# perimeter_se                  1.61       2.29         3.36          21.98
# area_se                      17.85      24.53        45.19         542.20
# smoothness_se                 0.01       0.01         0.01           0.03
# compactness_se                0.01       0.02         0.03           0.14
# concavity_se                  0.02       0.03         0.04           0.40
# concave points_se             0.01       0.01         0.01           0.05
# symmetry_se                   0.02       0.02         0.02           0.08
# fractal_dimension_se          0.00       0.00         0.00           0.03
# radius_worst                 13.01      14.97        18.79          36.04
# texture_worst                21.08      25.41        29.72          49.54
# perimeter_worst              84.11      97.66       125.40         251.20
# area_worst                  515.30     686.50     1,084.00       4,254.00
# smoothness_worst              0.12       0.13         0.15           0.22
# compactness_worst             0.15       0.21         0.34           1.06
# concavity_worst               0.11       0.23         0.38           1.25
# concave points_worst          0.06       0.10         0.16           0.29
# symmetry_worst                0.25       0.28         0.32           0.66
# fractal_dimension_worst       0.07       0.08         0.09           0.21
# Unnamed: 32                    NaN        NaN          NaN            NaN

# %% [markdown]
# ## 4. Distribución de la variable objetivo
#
# En este dataset la variable objetivo suele llamarse `diagnosis`, donde:
# - `M` = maligno
# - `B` = benigno

# %%
# Variable objetivo: columna o característica que se quiere predecir o explicar en un modelo de machine learning.
print(df["diagnosis"].value_counts())
print("\nProporciones:")
print(df["diagnosis"].value_counts(normalize=True))
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64
#
# Proporciones:
# diagnosis
# B   0.63
# M   0.37
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(4,4))
sns.countplot(x="diagnosis", data=df)
plt.title("Distribución de la variable objetivo (diagnosis)")
plt.show()

# %% [markdown]
# ## 5. Valores faltantes

# %%
# Serie con la cantidad de valores faltantes por columna
faltantes = df.isna().sum()

# Serie con la cantidad de valores faltantes por columna
faltantes[faltantes > 0]
# Out:
# Unnamed: 32    569
# dtype: int64

# %% [markdown]
# ## 6. Correlación entre variables numéricas (visión general)
#
# Aquí solo vemos un mapa de calor general para identificar posibles patrones.

# %%
df_numericas = df.select_dtypes(include=["int64", "float64"])

if df_numericas.shape[1] > 1:
    plt.figure(figsize=(10, 8))
    sns.heatmap(df_numericas.corr(), cmap="viridis")
    plt.title("Mapa de calor de correlaciones (variables numéricas)")
    plt.tight_layout()
    plt.show()
else:
    print("No hay suficientes variables numéricas para calcular correlaciones.")

# %% [markdown]
# ## 7. Conclusiones iniciales
#
# - Revisar el balance de clases en `diagnosis`.
# - Identificar posibles variables con valores extremos o muy correlacionadas.
# - Detectar si hay valores faltantes que deban tratarse en la etapa de limpieza.
#
# En el siguiente notebook realizaremos la **limpieza y preparación de los datos**.
